# %% [markdown]
# <a href="https://colab.research.google.com/github/niranj14/ict_assignments/blob/main/assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
item1_price = float(input("Enter the price of item 1: "))
item1_quantity = int(input("Enter the quantity of item 1: "))

item2_price = float(input("Enter the price of item 2: "))
item2_quantity = int(input("Enter the quantity of item 2: "))

total_bill = (item1_price * item1_quantity) + (item2_price * item2_quantity)

print(f"The total bill amount is: ${total_bill:.2f}")
# Out:
# Enter the price of item 1: 100
# Enter the quantity of item 1: 5
# Enter the price of item 2: 74
# Enter the quantity of item 2: 6
# The total bill amount is: $944.00

# %%
celsius = float(input("Enter temperature in Celsius: "))
fahrenheit = (celsius * 9/5) + 32
print(f"{celsius}°C is equal to {fahrenheit}°F")
# Out:
# Enter temperature in Celsius: 27
# 27.0°C is equal to 80.6°F

# %%
basic_salary = float(input("Enter the basic salary: "))

hra = 0.20 * basic_salary
da = 0.10 * basic_salary

total_salary = basic_salary + hra + da

print(f"Basic Salary: ${basic_salary:.2f}")
print(f"HRA (20%): ${hra:.2f}")
print(f"DA (10%): ${da:.2f}")
print(f"Total Salary: ${total_salary:.2f}")
# Out:
# Enter the basic salary: 20000
# Basic Salary: $20000.00
# HRA (20%): $4000.00
# DA (10%): $2000.00
# Total Salary: $26000.00

# %%
principal = float(input("Enter the principal amount (P): "))
rate = float(input("Enter the annual interest rate (R in %): "))
time = float(input("Enter the time period (T in years): "))

simple_interest = (principal * rate * time) / 100

print(f"The Simple Interest (SI) is: ${simple_interest:.2f}")
# Out:
# Enter the principal amount (P): 10000
# Enter the annual interest rate (R in %): 2.8
# Enter the time period (T in years): 5
# The Simple Interest (SI) is: $1400.00

# %%
original_price = float(input("Enter the original price of the item: "))

discount_percentage = 10
discount_amount = (original_price * discount_percentage) / 100

discounted_price = original_price - discount_amount

print(f"Original Price: ${original_price:.2f}")
print(f"Discount ({discount_percentage}%): ${discount_amount:.2f}")
print(f"Discounted Price: ${discounted_price:.2f}")
# Out:
# Enter the original price of the item: 100
# Original Price: $100.00
# Discount (10%): $10.00
# Discounted Price: $90.00

# %%
import math

# Get the lengths of the three sides from the user
side_a = float(input("Enter the length of side a: "))
side_b = float(input("Enter the length of side b: "))
side_c = float(input("Enter the length of side c: "))

# Calculate the semi-perimeter
s = (side_a + side_b + side_c) / 2

# Check if the sides form a valid triangle
if s <= side_a or s <= side_b or s <= side_c:
    print("Error: The given sides do not form a valid triangle.")
else:
    # Calculate the area using Heron's formula
    area = math.sqrt(s * (s - side_a) * (s - side_b) * (s - side_c))
    print(f"The area of the triangle is: {area:.2f}")
# Out:
# Enter the length of side a: 10
# Enter the length of side b: 15
# Enter the length of side c: 14
# The area of the triangle is: 67.71

# %%
print("Let's calculate the cost to paint a rectangular wall.")

# Get wall dimensions from the user
wall_length = float(input("Enter the length of the wall (in meters): "))
wall_height = float(input("Enter the height of the wall (in meters): "))

# Calculate total wall area
wall_area = wall_length * wall_height

# Window dimensions and count
window_length = 1.5  # meters
window_height = 1.2  # meters
num_windows = 2

# Calculate area of one window
window_area_single = window_length * window_height

# Calculate total area of all windows
total_window_area = window_area_single * num_windows

# Calculate the area to be painted
area_to_paint = wall_area - total_window_area

# Cost per square meter
cost_per_sq_meter = 25  # ₹

# Calculate total painting cost
total_painting_cost = area_to_paint * cost_per_sq_meter

print(f"\nTotal wall area: {wall_area:.2f} sq meters")
print(f"Total area of {num_windows} windows: {total_window_area:.2f} sq meters")
print(f"Area to be painted: {area_to_paint:.2f} sq meters")
print(f"Cost per square meter: ₹{cost_per_sq_meter:.2f}")
print(f"Total cost to paint: ₹{total_painting_cost:.2f}")
# Out:
# Let's calculate the cost to paint a rectangular wall.
# Enter the length of the wall (in meters): 1.3
# Enter the height of the wall (in meters): 1.8
#
# Total wall area: 2.34 sq meters
# Total area of 2 windows: 3.60 sq meters
# Area to be painted: -1.26 sq meters
# Cost per square meter: ₹25.00
# Total cost to paint: ₹-31.50

# %%
units_consumed = float(input("Enter the number of units consumed: "))

rate_per_unit = 5.2
fixed_charge = 100

variable_charge = units_consumed * rate_per_unit
total_bill_amount = variable_charge + fixed_charge

print(f"Units Consumed: {units_consumed:.2f}")
print(f"Rate per Unit: ₹{rate_per_unit:.2f}")
print(f"Fixed Charge: ₹{fixed_charge:.2f}")
print(f"Variable Charge: ₹{variable_charge:.2f}")
print(f"Total Bill Amount: ₹{total_bill_amount:.2f}")
# Out:
# Enter the number of units consumed: 500
# Units Consumed: 500.00
# Rate per Unit: ₹5.20
# Fixed Charge: ₹100.00
# Variable Charge: ₹2600.00
# Total Bill Amount: ₹2700.00
